# %% [markdown]
# #### Function 'print()' simply prints something in the screen.
#
# In below snippet, computer prints 'Hello world!' in the screen.

# %%
print('Hello world!')
# Out:
# Hello world!

# %% [markdown]
# The content must be surrounded by a pair of quotation marks. Both single and double quotation marks are acceptable.

# %%
print("Hello world double quotation!")
print('Hello world single quotation!')
# Out:
# Hello world double quotation!
# Hello world single quotation!

# %% [markdown]
# Special symbols in the content need to be "skipped" by a slash (\). An example is shown in below snippet.

# %%
print('I\'m a student')
# Out:
# I'm a student

# %% [markdown]
# Actually, in above example we may use a pair of double quotation marks to enclose the content, and the prime (') does not need to be skipped in this case, as the computer realizes the prime is not part of the quotation marks.

# %%
print("I'm a student")
# Out:
# I'm a student

# %% [markdown]
# #### Function 'input()' takes user input from console.
#
# In below snippet, computer pauses and waits for user to type something and then assigns it to the variable 'user_name1'. This function will not stop until user type something in the console.

# %%
user_name1 = input()
# Out:
#  John

# %% [raw]
# Function 'input' can also print a comment. In before snippet, computer prints a comment 'What is your name? ', and then pauses to wait for user's input. If I type 'John', variable 'user_name2' has the value of 'John'. Then the second line prints 'Hello, John' in the screen.

# %%
user_name2 = input('What is your name? ') # Computer pauses and waits for user input.
print('Hello,', user_name2)
# Out:
# What is your name?  John
# Hello, John

# %% [markdown]
# #### Variables:
#
# A variable has a name and can be used to hold values.
#
# A variable name must:
# 1. start with a letter or underscore (_),
# 2. contains only alpha-numeric characters and underscores,
# 3. not be Pyhon keywords, such as 'if', 'else', 'while', etc.
#
# Examples of acceptable variable names: 'a_number', '_number', 'number1'.
# Examples of unaccetable variable names: '1_number', 'number$', 'if'.
#
# Variable names are case sensitive. For example, "a_number" and "A_Number" are two different variables.
#
# There is no strict requirement for variable naming convention. It is preferred to use the "snake case" style, e.g., lowercase workds connected by under scores. For example, "a_good_variable_name".
#
# In Python, we don't have to tell the computer if a variable is a number, a string, or a boolean. The computer will decide based on the value we assign this variable. In below snippet, the three variables are float (decimal number), string, and boolean (True of False), respectively.

# %%
a_number = 1.0
a_string = "John is smart."
a_boolean = True

# %% [markdown]
# In below snippet, we print out the types of these variables. Note function 'type()' is used to check the type of variables.

# %%
print(type(a_number))
print(type(a_string))
print(type(a_boolean))
# Out:
# <class 'float'>
# <class 'str'>
# <class 'bool'>
